# %%
# Adapted from Anthropic Claude API Course
# Modified and extended for learning and experimentation

# %% [markdown]
# ## Environment Set-Up

# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Downloading anthropic-0.118.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-0.118.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.7 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.118.0

# %%
# Load env variables
from dotenv import load_dotenv
import os

print("API key loaded:", load_dotenv())
# Out:
# API key loaded: False

# %%
# Create API client
from anthropic import Anthropic

client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))
model = "claude-sonnet-4-0"

# %% [markdown]
# ## Making a Request using Claude API

# %%
# Make a request
message = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = [
        {
            "role": "user",
            "content": "What is quantum computing? Answer in 1 sentence."
        }
    ]
)
# Out:
# /tmp/ipykernel_479/64513854.py:2: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = client.messages.create(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/64513854.py in <cell line: 0>()
#       1 # Make a request
# ----> 2 message = client.messages.create(
#       3     model = model,
#       4     max_tokens = 1000,
#       5     messages = [
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_utils/_utils.py in wrapper(*args, **kwargs)
#     292                         msg = f"Missing required argument: {quote(missing[0])}"
#     293                 raise TypeError(msg)
# --> 294             return func(*args, **kwargs)
#     295
#     296         return wrapper  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/anthropic/resources/messages/messages.py in create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1048
#    1049         extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1050         return self._post(
#    1051             "/v1/messages",
#    1052             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_base_client.py in post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1534             method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535         )
# -> 1536         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1537
#    1538     def patch(
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1135             try:
#    1136                 if chain is None:
# -> 1137                     response, prepared = self._attempt_request(
#    1138                         model_copy(input_options), stream=stream, retries_taken=retries_taken
#    1139                     )
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_base_client.py in _attempt_request(self, options, stream, retries_taken)
#    1280         options = self._prepare_options(options)
#    1281
# -> 1282         request = self._build_request(options, retries_taken=retries_taken)
#    1283         self._prepare_request(request)
#    1284
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_base_client.py in _build_request(self, options, retries_taken)
#     537                 raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
#     538
# --> 539         headers = self._build_headers(options, retries_taken=retries_taken)
#     540         params = _merge_mappings(self.default_query, options.params)
#     541         content_type = headers.get("Content-Type")
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_base_client.py in _build_headers(self, options, retries_taken)
#     467         )
#     468         headers_dict = _strip_omit(merged_headers)
# --> 469         self._validate_headers(headers_dict, custom_headers)
#     470
#     471         # headers are case-insensitive while dictionaries are not.
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_client.py in _validate_headers(self, headers, custom_headers)
#     390             return
#     391
# --> 392         raise TypeError(
#     393             '"Could not resolve authentication method. Expected one of api_key, auth_token, or credentials to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     394         )
#
# TypeError: "Could not resolve authentication method. Expected one of api_key, auth_token, or credentials to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
message

# %%
message.content[0].text

# %% [markdown]
# ## Multi-Turn Conversations

# %%
# helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
print(messages)

# %%
print(final_answer)

# %% [markdown]
# ## Chat Excercise

# %%
# Make an initial list of messages
messages = []

# Run the chatbot forever, using the while True loop
while True:
    # Get user input
    user_input = input("User: ")
    print("User:", user_input)

    # Add user input to the list of messages
    add_user_message(messages, user_input)
    # Call Claude with the 'chat' function
    response = chat(messages)
    # Add generated text to the list of messages
    add_assistant_message(messages, response)
    # Print the generated text
    print("Claude:", response)
